# %%
using LmaPredict, PyPlot
using Base.Iterators: partition
using Flux
using Flux.Optimise: update!
using Flux.Losses: logitbinarycrossentropy
using Statistics
using Random

# %%
path_plot="/Users/alessandroconigli/Desktop/postdoc-mainz/projects/MLtoLMA"
path_config = "/Users/alessandroconigli/Lattice/data/HVP/LMA/A654/"
# Out:
# "/Users/alessandroconigli/Lattice/data/HVP/LMA/A654/"

# %%
## Reading data 
fname = readdir(path_config)
idx_cut = findall(x->x<=2000, parse.(Int64, fname))
fname = fname[idx_cut]
idx = sortperm( parse.(Int64, fname))
fname = fname[idx]

cnfgarr = Vector{LMAConfig}(undef, 0)
for f in fname
    push!(cnfgarr, get_LMAConfig(joinpath(path_config, f), "g5-g5", em="PA", bc=false))
end

# %%
## data manipulation to stadard WHCN to feed model

NCNFG = length(cnfgarr)
TVALS = length(cnfgarr[1].data["rr"]["0"]) 

TSRC_rr = collect(keys(getfield(cnfgarr[1], :data)["rr"] ))
TSRC_re = collect(keys(getfield(cnfgarr[1], :data)["re"] ))
# the sources has to be the same for both rr and ee

rr_re_images = Vector{Array{Float64}}(undef, TVALS)

for t in 1:TVALS    

    rr_re_images[t] = Array{Float64}(undef, 2, 1, length(TSRC_rr), NCNFG)
    for n in 1:NCNFG
        for (k,ts) in enumerate(TSRC_rr)
            rr_aux = getfield(cnfgarr[n], :data)["rr"][ts][t]
            re_aux = getfield(cnfgarr[n], :data)["re"][ts][t]
            
            rr_re_images[t][:,:,k, n] = [rr_aux, re_aux] 
        end
    end
end

# %%
# A vector for each TVALS
rr_re_images |> size
# Out:
# (48,)

# %%
# batch dimensions
rr_re_images[1] |> size
# Out:
# (2, 1, 4, 2000)

# %%
function discriminator()
    dscr = Chain(
        Dense(2 => 32, leakyrelu),
        Dropout(0.3),
        Dense(32 => 16, leakyrelu),
        Dropout(0.3),
        Dense(16 => 1, sigmoid)
    )
    return dscr
end

#dscr = discriminator()
#dscr(rr_re_images[1])
# Out:
# discriminator (generic function with 1 method)

# %%
function generator(latent_dim::Int)
    gen = Chain(
        Dense(latent_dim => 16, leakyrelu),
        Dense(16 => 8, leakyrelu),
        Dense(8 => 2)
    )
    return gen
end
# Out:
# generator (generic function with 1 method)

# %%
function generate_noise(hparams)
    noise = randn(hparams.latent_dim, hparams.batch_size)
    return noise
end
# Out:
# generate_noise (generic function with 1 method)

# %%
function generate_fake_sample(gen, hparams)
    noise = generate_noise(hparams)
    return gen(noise)
end
# Out:
# generate_fake_sample (generic function with 1 method)

# %%
# Loss functions
function discriminator_loss(real_sample, fake_sample)
    
    real_loss = logitbinarycrossentropy(real_sample, 1)
    fake_loss = logitbinarycrossentropy(fake_sample, 0)
    return real_loss + fake_loss
end

generator_loss(fake_sample) = logitbinarycrossentropy(fake_sample, 1)
# Out:
# generator_loss (generic function with 1 method)

# %%
function train_discriminator!(gen, dscr, real_sample, opt_discr, hparams)
    
    fake_sample = generate_fake_sample(gen, hparams) 
    
    loss, grad = Flux.withgradient(dscr) do dscr
        discriminator_loss(dscr(real_sample), dscr(fake_sample))
    end
    
    update!(opt_discr, dscr, grad[1])
    return loss
end

function train_generator!(gen, dscr, opt_gen, hparams)
    
    noise = generate_noise(hparams)
    
    loss, grad = Flux.withgradient(gen) do gen
        generator_loss(dscr(gen(noise)))
    end
    
    update!(opt_gen, gen, grad[1])
    return loss
end
# Out:
# train_generator! (generic function with 1 method)

# %%
function train!(data::Array{Float64,4}, dscr, gen, hparams::HyperParams; kws...)
    #hparams = HyperParams()

    data_batches = [data[:,:,:,k] for k in partition(1:size(data,4), hparams.batch_size)]

    # dscr = discriminator()
    # gen  = generator(hparams.latent_dim) 

    # optimizers
    opt_dscr = Flux.setup(Adam(hparams.lr_dscr), dscr)
    opt_gen = Flux.setup(Adam(hparams.lr_gen), gen)

    store_loss_dscr = []
    store_loss_gen  = []

    # training
    train_steps = 0
    for ep in 1:hparams.epochs
        for d_batch in data_batches
            loss_dscr = train_discriminator!(gen, dscr, d_batch, opt_dscr, hparams)
            loss_gen  = train_generator!(gen, dscr, opt_gen, hparams) 

            push!(store_loss_dscr, loss_dscr)
            push!(store_loss_gen, loss_gen)
            
            if train_steps % hparams.verbose_freq == 0 
                @info "Epoch $(ep): train step: $(train_steps), dscr loss: $(loss_dscr), gen loss: $(loss_gen)"
            end
            train_steps +=1
        end
    end
    plot(store_loss_dscr, label="dscr loss")
    plot(store_loss_gen, label="gen loss")
    legend()
    display(gcf())
    close("all")
    
    return gen, dscr
end
# Out:
# train! (generic function with 2 methods)

# %%
# HyperParams
Base.@kwdef struct HyperParams
    batch_size::Int = 200
    latent_dim::Int = 100
    epochs::Int = 500
    verbose_freq::Int = 1000
    output_x::Int = 6
    output_y::Int = 6
    lr_dscr::Float32 = 0.0002
    lr_gen::Float32 = 0.0002
end
# Out:
# HyperParams

# %%
hp = HyperParams()

gen_tot  = [generator(hp.latent_dim) for t in 1:TVALS]
dscr_tot = [discriminator() for t in 1:TVALS] 

for t in 1:20
    train!(rr_re_images[t][:,:,:,:], dscr_tot[t], gen_tot[t], hp)    
end
# Out:
# [ Info: Epoch 1: train step: 0, dscr loss: 1.4855076610407363, gen loss: 0.47841952530928356
# [ Info: Epoch 101: train step: 1000, dscr loss: 1.376714261419337, gen loss: 0.6286335975704102
# [ Info: Epoch 201: train step: 2000, dscr loss: 1.36752785688671, gen loss: 0.6313209232941851
# [ Info: Epoch 301: train step: 3000, dscr loss: 1.3766627645289855, gen loss: 0.6160026915929798
# [ Info: Epoch 401: train step: 4000, dscr loss: 1.3773235296667072, gen loss: 0.6152385786116071
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# [ Info: Epoch 1: train step: 0, dscr loss: 1.4461091544601141, gen loss: 0.4748578211574683
# [ Info: Epoch 101: train step: 1000, dscr loss: 1.3954676795706518, gen loss: 0.604125345979826
# [ Info: Epoch 201: train step: 2000, dscr loss: 1.3880587330136855, gen loss: 0.6669234126312726
# [ Info: Epoch 301: train step: 3000, dscr loss: 1.3878789988010591, gen loss: 0.6799598239914895
# [ Info: Epoch 401: train step: 4000, dscr loss: 1.386209374577934, gen loss: 0.685170309701253
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# [ Info: Epoch 1: train step: 0, dscr loss: 1.4778088045855515, gen loss: 0.4582346984875633
# [ Info: Epoch 101: train step: 1000, dscr loss: 1.39158172739084, gen loss: 0.6008789210266738
# [ Info: Epoch 201: train step: 2000, dscr loss: 1.3893711297884401, gen loss: 0.6618084824489197
# [ Info: Epoch 301: train step: 3000, dscr loss: 1.3862697020006611, gen loss: 0.6765057672857411
# [ Info: Epoch 401: train step: 4000, dscr loss: 1.386742268727951, gen loss: 0.6863965564166069
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# [ Info: Epoch 1: train step: 0, dscr loss: 1.5387929199421386, gen loss: 0.42187177018985605
# [ Info: Epoch 101: train step: 1000, dscr loss: 1.3851222749872045, gen loss: 0.5645289828604305
# [ Info: Epoch 201: train step: 2000, dscr loss: 1.3882457587218862, gen loss: 0.6422467331330478
# [ Info: Epoch 301: train step: 3000, dscr loss: 1.3892034924957113, gen loss: 0.670275005258858
# [ Info: Epoch 401: train step: 4000, dscr loss: 1.3873354683493493, gen loss: 0.6806996986811648
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# [ Info: Epoch 1: train step: 0, dscr loss: 1.4479627188871624, gen loss: 0.47765088266019307
# [ Info: Epoch 101: train step: 1000, dscr loss: 1.3925837266543657, gen loss: 0.6247000126803471
# [ Info: Epoch 201: train step: 2000, dscr loss: 1.385059730063937, gen loss: 0.6748247365065361
# [ Info: Epoch 301: train step: 3000, dscr loss: 1.3871516046340036, gen loss: 0.6835649174181674
# [ Info: Epoch 401: train step: 4000, dscr loss: 1.3876929996339653, gen loss: 0.6865230199421463
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# [ Info: Epoch 1: train step: 0, dscr loss: 1.435348033730996, gen loss: 0.48868985048770597
# [ Info: Epoch 101: train step: 1000, dscr loss: 1.3850265452469768, gen loss: 0.5758530919403446
# [ Info: Epoch 201: train step: 2000, dscr loss: 1.386087250486514, gen loss: 0.6427144914178043
# [ Info: Epoch 301: train step: 3000, dscr loss: 1.3866261630153198, gen loss: 0.6696534321084091
# [ Info: Epoch 401: train step: 4000, dscr loss: 1.3851899140126054, gen loss: 0.6775669740005545
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# [ Info: Epoch 1: train step: 0, dscr loss: 1.4569894189765007, gen loss: 0.47393152569431274
# [ Info: Epoch 101: train step: 1000, dscr loss: 1.4027698454475308, gen loss: 0.5799209111308287
# [ Info: Epoch 201: train step: 2000, dscr loss: 1.3880806233676282, gen loss: 0.6524311802036545
# [ Info: Epoch 301: train step: 3000, dscr loss: 1.388277372054716, gen loss: 0.675340022353277
# [ Info: Epoch 401: train step: 4000, dscr loss: 1.387515302908973, gen loss: 0.6809490496583418
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# [ Info: Epoch 1: train step: 0, dscr loss: 1.455817209619612, gen loss: 0.47039363618661795
# [ Info: Epoch 101: train step: 1000, dscr loss: 1.3923773282014218, gen loss: 0.6115127834697618
# [ Info: Epoch 201: train step: 2000, dscr loss: 1.3871170939150983, gen loss: 0.6712461077959478
# [ Info: Epoch 301: train step: 3000, dscr loss: 1.3866049953638035, gen loss: 0.6826719642462183
# [ Info: Epoch 401: train step: 4000, dscr loss: 1.3869866178515025, gen loss: 0.6857619215556519
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# [ Info: Epoch 1: train step: 0, dscr loss: 1.4176983549247024, gen loss: 0.49473576152913007
# [ Info: Epoch 101: train step: 1000, dscr loss: 1.385056610424379, gen loss: 0.5714496823071604
# [ Info: Epoch 201: train step: 2000, dscr loss: 1.390417124626094, gen loss: 0.6471927495494393
# [ Info: Epoch 301: train step: 3000, dscr loss: 1